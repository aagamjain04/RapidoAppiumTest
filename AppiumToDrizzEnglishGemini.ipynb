# %% [markdown]
# <a href="https://colab.research.google.com/github/aagamjain04/RapidoAppiumTest/blob/main/AppiumToDrizzEnglishGemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai

def translate_appium_code(appium_code, api_key):

    try:

        genai.configure(api_key=api_key)


        model = genai.GenerativeModel('gemini-pro')

        prompt = f"""
        Please translate this Appium automation code into plain English, describing what each line does and print only print translated line:
        Translated english should be in the format
        SET_GPS(latitude=12.8832, longitude=77.5250)
        Click on Where are you going? input text box
        Enter Majestic Bus Stand in Drop location input text box
        Select Majestic Bus Stand option from the list below Select on map button
        Validate that red and green coloured pins are connect via a polyline on the map
        Click on Book Auto button
        Validate that text "Confirm Pickup" is present on the screen
        Click on Confirm Pickup
        EXECUTE_API: rider_status_online
        Click on Book Auto CTA button
        EXECUTE_API: rider_ping_ack
        EXECUTE_API: rider_ping_accept
        Click on X to close the bottom sheet
        Validate that text "Captain on the way" is present on the screen
        Validate that Start pin is 8964
        Validate that pickup is from Bengaluru
        Validate that HR23ID323 is present on the screen
        EXECUTE_API: order_status_arrived
        Validate that Captain arrived is present on the screen
        Validate that timer is present on the screen
        EXECUTE_API: order_status_started
        Validate that map is present on the screen
        EXECUTE_API: order_status_dropped
        Validate that map is not present on the screen
        EXECUTE_API: order_payment_collected
        Validate that map is not present on the screen
        EXECUTE_API: order_feedback_rider
        Validate that map is not present on the screen
        EXECUTE_API: rider_status_offline


        {appium_code}
        """

        # Generate the response
        response = model.generate_content(prompt)

        return response.text

    except Exception as e:
        return f"Error occurred during translation: {str(e)}"

if __name__ == "__main__":
    # Your API key
    API_KEY = "AIzaSyBSseajfE-Rs7FLPVXhefYMYVM2I6YDl04"

    # Sample Appium code
    appium_code = """
    # Click search field
            search_field = self.wait.until(
                EC.presence_of_element_located(
                    (AppiumBy.ANDROID_UIAUTOMATOR, 'new UiSelector().resourceId("search_field")')
                )
            )
            search_field.click()

            # Click drop text field
            drop_text = self.wait.until(
                EC.presence_of_element_located(
                    (AppiumBy.ACCESSIBILITY_ID, "Double tap to enter Drop Location. Enter at least 3 characters to get suggestions below")
                )
            )
            drop_text.click()

            # Type the drop location
            self.type_text_using_keycodes("Majestic Bus Stand")

            # Wait and click drop location suggestion
            time.sleep(2)
            drop_location = self.wait.until(
                EC.presence_of_element_located(
                    (AppiumBy.ANDROID_UIAUTOMATOR, 'new UiSelector().className("android.view.View").instance(7)')
                )
            )
            drop_location.click()

            # Select auto ride
            time.sleep(2)
            auto_select = self.wait.until(
                EC.presence_of_element_located(
                    (AppiumBy.ANDROID_UIAUTOMATOR, 'new UiSelector().descriptionMatches("Get Auto.*")')
                )
            )
            auto_select.click()

            # Click the book button
            book_button = self.wait.until(
                EC.presence_of_element_located(
                    (AppiumBy.ANDROID_UIAUTOMATOR, 'new UiSelector().description("Double tap to book Auto")')
                )
            )
            book_button.click()

            # Verify the confirm pickup button is displayed
            confirm_pickup = self.wait.until(
                EC.presence_of_element_located(
                    (AppiumBy.ANDROID_UIAUTOMATOR, 'new UiSelector().resourceId("base_select_from_map_confirm_button")')
                )
            )
            self.assertTrue(confirm_pickup.is_displayed(), "Confirm Pickup button is not displayed")

    """

    # Get the translation
    translation = translate_appium_code(appium_code, API_KEY)
    print("\nTranslation:")
    print(translation)
# Out:
# Translation:
# Click on Where are you going? input text box
# Enter Majestic Bus Stand in Drop location input text box
# Select Majestic Bus Stand option from the list below Select on map button
# Click on Book Auto button
# Validate that text "Confirm Pickup" is present on the screen
# Click on Confirm Pickup
